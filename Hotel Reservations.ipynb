# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
hotel_df=pd.read_csv("Hotel Reservations.csv")

# %%
hotel_df.head(50)
# Out:
#    Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0    INN00001             2               0                     1
# 1    INN00002             2               0                     2
# 2    INN00003             1               0                     2
# 3    INN00004             2               0                     0
# 4    INN00005             2               0                     1
# 5    INN00006             2               0                     0
# 6    INN00007             2               0                     1
# 7    INN00008             2               0                     1
# 8    INN00009             3               0                     0
# 9    INN00010             2               0                     0
# 10   INN00011             1               0                     1
# 11   INN00012             1               0                     2
# 12   INN00013             2               0                     2
# ...

# %%
df_copy=hotel_df.copy()

# %%
def BasicInfo(df):
    """ 
    Prints basic information such as shape, columns with missing values, 
    etc about any input dataframe.
    
    """
    print('='*50)
    print(f'Shape of the dataframe: {df.shape}')
    print('='*50)
    print(df.info())
    print('='*50)
    print(f'Column names:{df.columns}')
    print('='*50)
    null_cols = [col for col in df.columns if df[col].isnull().sum() != 0]
    print(f'Columns with missing values: {null_cols}')
    print('='*50)

# %%
BasicInfo(df_copy)
# Out:
# ...
# Shape of the dataframe: (36275, 19)
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
# ...

# %%
df_copy['arrival_month'].value_counts()
# Out:
# 10    5317
# 9     4611
# 8     3813
# 6     3203
# 12    3021
# 11    2980
# 7     2920
# 4     2736
# 5     2598
# 3     2358
# 2     1704
# 1     1014
# Name: arrival_month, dtype: int64

# %%
df_copy['no_of_adults'].value_counts()
# Out:
# 2    26108
# 1     7695
# 3     2317
# 0      139
# 4       16
# Name: no_of_adults, dtype: int64

# %%
df_copy['no_of_children'].value_counts()
# Out:
# 0     33577
# 1      1618
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: no_of_children, dtype: int64

# %%
df_copy['no_of_weekend_nights'].value_counts()
# Out:
# 0    16872
# 1     9995
# 2     9071
# 3      153
# 4      129
# 5       34
# 6       20
# 7        1
# Name: no_of_weekend_nights, dtype: int64

# %%
df_copy['no_of_week_nights'].value_counts()
# Out:
# 2     11444
# 1      9488
# 3      7839
# 4      2990
# 0      2387
# 5      1614
# 6       189
# 7       113
# 10       62
# 8        62
# 9        34
# 11       17
# 15       10
# 12        9
# 14        7
# 13        5
# 17        3
# 16        2
# Name: no_of_week_nights, dtype: int64

# %%
df_copy['type_of_meal_plan'].value_counts()
# Out:
# Meal Plan 1     27835
# Not Selected     5130
# Meal Plan 2      3305
# Meal Plan 3         5
# Name: type_of_meal_plan, dtype: int64

# %%
df_copy['required_car_parking_space'].value_counts()
# Out:
# 0    35151
# 1     1124
# Name: required_car_parking_space, dtype: int64

# %%
df_copy[ 'room_type_reserved'].value_counts()
# Out:
# Room_Type 1    28130
# Room_Type 4     6057
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: room_type_reserved, dtype: int64

# %%
df_copy['lead_time'].value_counts()
# Out:
# 0      1297
# 1      1078
# 2       643
# 3       630
# 4       628
#        ...
# 300       1
# 353       1
# 328       1
# 352       1
# 351       1
# Name: lead_time, Length: 352, dtype: int64

# %%
df_copy['arrival_year'].value_counts()
# Out:
# 2018    29761
# 2017     6514
# Name: arrival_year, dtype: int64

# %%
df_copy['arrival_month'].value_counts()
# Out:
# 10    5317
# 9     4611
# 8     3813
# 6     3203
# 12    3021
# 11    2980
# 7     2920
# 4     2736
# 5     2598
# 3     2358
# 2     1704
# 1     1014
# Name: arrival_month, dtype: int64

# %%
df_copy['arrival_date'].value_counts()
# Out:
# 13    1358
# 17    1345
# 2     1331
# 4     1327
# 19    1327
# 16    1306
# 20    1281
# 15    1273
# 6     1273
# 18    1260
# 14    1242
# 30    1216
# 12    1204
# 8     1198
# 29    1190
# 21    1158
# 5     1154
# 26    1146
# 25    1146
# 1     1133
# 9     1130
# 28    1129
# 7     1110
# 24    1103
# 11    1098
# 3     1098
# 10    1089
# 27    1059
# 22    1023
# 23     990
# 31     578
# Name: arrival_date, dtype: int64

# %%
df_copy['market_segment_type'].value_counts()
# Out:
# Online           23214
# Offline          10528
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: market_segment_type, dtype: int64

# %%
df_copy['repeated_guest'].value_counts()
# Out:
# 0    35345
# 1      930
# Name: repeated_guest, dtype: int64

# %%
df_copy['no_of_previous_cancellations'].value_counts()
# Out:
# 0     35937
# 1       198
# 2        46
# 3        43
# 11       25
# 5        11
# 4        10
# 13        4
# 6         1
# Name: no_of_previous_cancellations, dtype: int64

# %%
df_copy[ 'no_of_previous_bookings_not_canceled'].value_counts()
# Out:
# 0     35463
# 1       228
# 2       112
# 3        80
# 4        65
# 5        60
# 6        36
# 7        24
# 8        23
# 10       19
# 9        19
# 11       15
# 12       12
# 14        9
# 15        8
# 16        7
# 13        7
# 18        6
# 20        6
# 21        6
# 17        6
# 19        6
# 22        6
# 25        3
# 27        3
# 24        3
# 23        3
# 44        2
# 29        2
# 48        2
# 28        2
# 30        2
# 32        2
# 31        2
# 26        2
# 46        1
# 55        1
# 45        1
# 57        1
# 53        1
# 54        1
# 58        1
# 41        1
# 40        1
# 43        1
# 35        1
# 50        1
# 56        1
# 33        1
# 37        1
# 42        1
# 51        1
# 38        1
# 34        1
# 39        1
# 52        1
# 49        1
# 47        1
# 36        1
# Name: no_of_previous_bookings_not_canceled, dtype: int64

# %%
df_copy[ 'avg_price_per_room'].value_counts()
# Out:
# 65.00     848
# 75.00     826
# 90.00     703
# 95.00     669
# 115.00    662
#          ...
# 212.42      1
# 83.48       1
# 70.42       1
# 130.99      1
# 167.80      1
# Name: avg_price_per_room, Length: 3930, dtype: int64

# %%
df_copy[ 'no_of_special_requests'].value_counts()
# Out:
# 0    19777
# 1    11373
# 2     4364
# 3      675
# 4       78
# 5        8
# Name: no_of_special_requests, dtype: int64

# %%
df_copy.describe()
# Out:
# <Axes: xlabel='booking_status', ylabel='count'>

# %%
sns.countplot(data=df_copy,
             x="booking_status",
             palette="Set2",
             hue="arrival_month")
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %%
sns.countplot(data=df_copy,
             x="market_segment_type",
             palette="Set2")
# Out:
# <Axes: xlabel='market_segment_type', ylabel='count'>

# %%
sns.countplot(data=df_copy,
             x="room_type_reserved",
             palette="Set2")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Room_Type 1'),
#   Text(1, 0, 'Room_Type 4'),
#   Text(2, 0, 'Room_Type 2'),
#   Text(3, 0, 'Room_Type 6'),
#   Text(4, 0, 'Room_Type 5'),
#   Text(5, 0, 'Room_Type 7'),
#   Text(6, 0, 'Room_Type 3')])

# %%
sns.countplot(data=df_copy,
             x="room_type_reserved",
             palette="Set2",
             hue="type_of_meal_plan")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Room_Type 1'),
#   Text(1, 0, 'Room_Type 4'),
#   Text(2, 0, 'Room_Type 2'),
#   Text(3, 0, 'Room_Type 6'),
#   Text(4, 0, 'Room_Type 5'),
#   Text(5, 0, 'Room_Type 7'),
#   Text(6, 0, 'Room_Type 3')])
